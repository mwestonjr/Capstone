# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import numpy_financial as npf

# %%
 pip install numpy-financial
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
home_sales = pd.read_csv('../capstone/data/avg_home_sale_price.csv')

# %%
home_sales
# Out:
#     Period United States Median Northeast Median Midwest Median South Median  \
# 0     1963               18,000           20,300         17,900       16,100
# 1     1964               18,900           20,300         19,400       16,700
# 2     1965               20,000           21,500         21,600       17,500
# 3     1966               21,400           23,500         23,200       18,200
# 4     1967               22,700           25,400         25,100       19,400
# ..     ...                  ...              ...            ...          ...
# 56    2019              321,500          482,500        289,200      289,000
# 57    2020              336,900          470,700        298,100      299,000
# 58    2021              397,100          560,900        339,900      355,900
# 59    2022              457,800          640,200        405,000      412,700
# 60    2023              427,400          756,200        394,700      386,900
#
# ...

# %%
home_sales['US Median'] = home_sales['United States Median'].str.replace(',','')

# %%
home_sales['NE Median'] = home_sales['Northeast Median'].str.replace(',','')

# %%
home_sales['MW Median'] = home_sales['Midwest Median'].str.replace(',','')

# %%
home_sales['South Median'] = home_sales['South Median'].str.replace(',','')

# %%
home_sales['West Median'] = home_sales['West Median'].str.replace(',','')

# %%
home_sales['US Avg'] = home_sales['United States Avg'].str.replace(',','')

# %%
home_sales['NE Avg'] = home_sales['Northeast Avg'].str.replace(',','')

# %%
home_sales['MW Avg'] = home_sales['Midwest Avg'].str.replace(',','')

# %%
home_sales['South Avg'] = home_sales['South Avg'].str.replace(',','')

# %%
home_sales['West Avg'] = home_sales['West Avg'].str.replace(',','')

# %%
home_sales = home_sales[['Period', 'US Median', 'NE Median', 'MW Median', 'South Median', 'West Median', 'US Avg', 'NE Avg', 'MW Avg', 'South Avg', 'West Avg']]

# %%
home_sales
# Out:
#     Period US Median NE Median MW Median South Median West Median  US Avg  \
# 0     1963     18000     20300     17900        16100       18800   19300
# 1     1964     18900     20300     19400        16700       20400   20500
# 2     1965     20000     21500     21600        17500       21600   21500
# 3     1966     21400     23500     23200        18200       23200   23300
# 4     1967     22700     25400     25100        19400       24100   24600
# ..     ...       ...       ...       ...          ...         ...     ...
# 56    2019    321500    482500    289200       289000      408000  383900
# 57    2020    336900    470700    298100       299000      412600  391900
# 58    2021    397100    560900    339900       355900      510400  464200
# 59    2022    457800    640200    405000       412700      578800  540000
# 60    2023    427400    756200    394700       386900      533800  511100
#
#     NE Avg  MW Avg South Avg West Avg
# 0    22300   19700     16800    20800
# ...

# %% [markdown]
# ### Source: https://www.census.gov/construction/nrs/data/series.html

# %%
home_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Period        61 non-null     int64
#  1   US Median     61 non-null     object
#  2   NE Median     61 non-null     object
#  3   MW Median     61 non-null     object
#  4   South Median  61 non-null     object
#  5   West Median   61 non-null     object
#  6   US Avg        61 non-null     object
#  7   NE Avg        61 non-null     object
#  8   MW Avg        61 non-null     object
#  9   South Avg     61 non-null     object
#  10  West Avg      61 non-null     object
# dtypes: int64(1), object(10)
# memory usage: 5.4+ KB

# %%
home_sales
# Out:
#     Period US Median NE Median MW Median South Median West Median  US Avg  \
# 0     1963     18000     20300     17900        16100       18800   19300
# 1     1964     18900     20300     19400        16700       20400   20500
# 2     1965     20000     21500     21600        17500       21600   21500
# 3     1966     21400     23500     23200        18200       23200   23300
# 4     1967     22700     25400     25100        19400       24100   24600
# ..     ...       ...       ...       ...          ...         ...     ...
# 56    2019    321500    482500    289200       289000      408000  383900
# 57    2020    336900    470700    298100       299000      412600  391900
# 58    2021    397100    560900    339900       355900      510400  464200
# 59    2022    457800    640200    405000       412700      578800  540000
# 60    2023    427400    756200    394700       386900      533800  511100
#
#     NE Avg  MW Avg South Avg West Avg
# 0    22300   19700     16800    20800
# ...

# %%
home_sales['US Median'] = home_sales['US Median'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\373776827.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['US Median'] = home_sales['US Median'].astype(int)

# %%
home_sales['NE Median'] = home_sales['NE Median'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\2869175379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['NE Median'] = home_sales['NE Median'].astype(int)

# %%
home_sales['MW Median'] = home_sales['MW Median'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\389982822.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['MW Median'] = home_sales['MW Median'].astype(int)

# %%
home_sales['South Median'] = home_sales['South Median'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\2410358796.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['South Median'] = home_sales['South Median'].astype(int)

# %%
home_sales['West Median'] = home_sales['West Median'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\3969649565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['West Median'] = home_sales['West Median'].astype(int)

# %%
home_sales['US Avg'] = home_sales['US Avg'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\526696819.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['US Avg'] = home_sales['US Avg'].astype(int)

# %%
home_sales['NE Avg'] = home_sales['NE Avg'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\2150974246.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['NE Avg'] = home_sales['NE Avg'].astype(int)

# %%
home_sales['MW Avg'] = home_sales['MW Avg'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\1798317811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['MW Avg'] = home_sales['MW Avg'].astype(int)

# %%
home_sales['South Avg'] = home_sales['South Avg'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\3520053034.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['South Avg'] = home_sales['South Avg'].astype(int)

# %%
home_sales['West Avg'] = home_sales['West Avg'].astype(int)
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\976543995.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['West Avg'] = home_sales['West Avg'].astype(int)

# %%
home_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Period        61 non-null     int64
#  1   US Median     61 non-null     int32
#  2   NE Median     61 non-null     int32
#  3   MW Median     61 non-null     int32
#  4   South Median  61 non-null     int32
#  5   West Median   61 non-null     int32
#  6   US Avg        61 non-null     int32
#  7   NE Avg        61 non-null     int32
#  8   MW Avg        61 non-null     int32
#  9   South Avg     61 non-null     int32
#  10  West Avg      61 non-null     int32
# dtypes: int32(10), int64(1)
# memory usage: 3.0 KB

# %%
home_sales
# Out:
#     Period  US Median  NE Median  MW Median  South Median  West Median  \
# 0     1963      18000      20300      17900         16100        18800
# 1     1964      18900      20300      19400         16700        20400
# 2     1965      20000      21500      21600         17500        21600
# 3     1966      21400      23500      23200         18200        23200
# 4     1967      22700      25400      25100         19400        24100
# ..     ...        ...        ...        ...           ...          ...
# 56    2019     321500     482500     289200        289000       408000
# 57    2020     336900     470700     298100        299000       412600
# 58    2021     397100     560900     339900        355900       510400
# 59    2022     457800     640200     405000        412700       578800
# 60    2023     427400     756200     394700        386900       533800
#
#     US Avg  NE Avg  MW Avg  South Avg  West Avg
# 0    19300   22300   19700      16800     20800
# ...

# %%
home_sales['US Median Pct Chng']= home_sales['US Median'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\1948988306.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['US Median Pct Chng']= home_sales['US Median'].pct_change()*100

# %%
home_sales['NE Median Pct Chng']= home_sales['NE Median'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\318292731.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['NE Median Pct Chng']= home_sales['NE Median'].pct_change()*100

# %%
home_sales['MW Median Pct Chng']= home_sales['MW Median'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\1569653972.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['MW Median Pct Chng']= home_sales['MW Median'].pct_change()*100

# %%
home_sales['South Median Pct Chng']= home_sales['South Median'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\1083461948.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['South Median Pct Chng']= home_sales['South Median'].pct_change()*100

# %%
home_sales['West Median Pct Chng']= home_sales['West Median'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\345850709.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_sales['West Median Pct Chng']= home_sales['West Median'].pct_change()*100

# %%
home_sales['US Avg Pct Chng']= home_sales['US Avg'].pct_change()*100

# %%
home_sales['NE Avg Pct Chng']= home_sales['NE Avg'].pct_change()*100

# %%
home_sales['MW Avg Pct Chng']= home_sales['MW Avg'].pct_change()*100

# %%
home_sales['South Avg Pct Chng']= home_sales['South Avg'].pct_change()*100

# %%
home_sales['West Avg Pct Chng']= home_sales['West Avg'].pct_change()*100

# %%
home_sales
# Out:
#     Period  US Median  NE Median  MW Median  South Median  West Median  \
# 0     1963      18000      20300      17900         16100        18800
# 1     1964      18900      20300      19400         16700        20400
# 2     1965      20000      21500      21600         17500        21600
# 3     1966      21400      23500      23200         18200        23200
# 4     1967      22700      25400      25100         19400        24100
# ..     ...        ...        ...        ...           ...          ...
# 56    2019     321500     482500     289200        289000       408000
# 57    2020     336900     470700     298100        299000       412600
# 58    2021     397100     560900     339900        355900       510400
# 59    2022     457800     640200     405000        412700       578800
# 60    2023     427400     756200     394700        386900       533800
#
#     US Avg  NE Avg  MW Avg  South Avg  ...  US Median Pct Chng  \
# ...

# %%
home_sales.to_csv('../capstone/data/homes_sales_BI.csv')

# %%
home_sales.plot(kind = 'line',
                x = 'Period',
                y = ['US Median','NE Median', 'MW Median', 'South Median', 'West Median'],
                figsize = (10,6))
# Out:
# <Axes: xlabel='Period'>

# %%
home_sales.plot(kind = 'line',
                x = 'Period',
                y = ['US Avg','NE Avg', 'MW Avg', 'South Avg', 'West Avg'],
                figsize = (10,6))
# Out:
# <Axes: xlabel='Period'>

# %%
value_by_quarter = pd.read_csv('../capstone/data/value_by_quarter.csv')

# %%
value_by_quarter
# Out:
#      Period  US Median  NE Median  MW Median  South Median  West Median  \
# 0    1963Q1      17800      20800      17500         16800        18000
# 1    1963Q2      18000      20600      17700         15800        18900
# 2    1963Q3      17900      19600      17800         15900        19000
# 3    1963Q4      18500      20600      19100         15800        19500
# 4    1964Q1      18500      20300      18700         16500        19600
# ..      ...        ...        ...        ...           ...          ...
# 239  2022Q4     479500     686600     355000        448600       564600
# 240  2023Q1     429000     727800     384900        385600       558200
# 241  2023Q2     418500     744500     393800        374300       543500
# 242  2023Q3     435400     893300     423100        394100       513200
# 243  2023Q4     417700     698000     363000        387300       517800
#
#      US Avg   NE Avg  MW Avg  South Avg  West Avg
# 0     19300        0       0          0         0
# ...

# %%
value_by_quarter[["Year", "Quarter"]] = value_by_quarter['Period'].str.split('Q', expand = True)

# %%
value_qrt = value_by_quarter.drop(columns=['Period'])
value_qrt
# Out:
#      US Median  NE Median  MW Median  South Median  West Median  US Avg  \
# 0        17800      20800      17500         16800        18000   19300
# 1        18000      20600      17700         15800        18900   19400
# 2        17900      19600      17800         15900        19000   19200
# 3        18500      20600      19100         15800        19500   19600
# 4        18500      20300      18700         16500        19600   19600
# ..         ...        ...        ...           ...          ...     ...
# 239     479500     686600     355000        448600       564600  552600
# 240     429000     727800     384900        385600       558200  505300
# 241     418500     744500     393800        374300       543500  503000
# 242     435400     893300     423100        394100       513200  521900
# 243     417700     698000     363000        387300       517800  492300
#
#       NE Avg  MW Avg  South Avg  West Avg  Year Quarter
# ...

# %%
value_by_quarter
# Out:
#      Period  US Median  NE Median  MW Median  South Median  West Median  \
# 0    1963Q1      17800      20800      17500         16800        18000
# 1    1963Q2      18000      20600      17700         15800        18900
# 2    1963Q3      17900      19600      17800         15900        19000
# 3    1963Q4      18500      20600      19100         15800        19500
# 4    1964Q1      18500      20300      18700         16500        19600
# ..      ...        ...        ...        ...           ...          ...
# 239  2022Q4     479500     686600     355000        448600       564600
# 240  2023Q1     429000     727800     384900        385600       558200
# 241  2023Q2     418500     744500     393800        374300       543500
# 242  2023Q3     435400     893300     423100        394100       513200
# 243  2023Q4     417700     698000     363000        387300       517800
#
#      US Avg   NE Avg  MW Avg  South Avg  West Avg  Year Quarter
# ...

# %%
value_qrt
# Out:
#      US Median  NE Median  MW Median  South Median  West Median  US Avg  \
# 0        17800      20800      17500         16800        18000   19300
# 1        18000      20600      17700         15800        18900   19400
# 2        17900      19600      17800         15900        19000   19200
# 3        18500      20600      19100         15800        19500   19600
# 4        18500      20300      18700         16500        19600   19600
# ..         ...        ...        ...           ...          ...     ...
# 239     479500     686600     355000        448600       564600  552600
# 240     429000     727800     384900        385600       558200  505300
# 241     418500     744500     393800        374300       543500  503000
# 242     435400     893300     423100        394100       513200  521900
# 243     417700     698000     363000        387300       517800  492300
#
#       NE Avg  MW Avg  South Avg  West Avg  Year Quarter
# ...

# %%
value_by_quarter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Period        244 non-null    object
#  1   US Median     244 non-null    int64
#  2   NE Median     244 non-null    int64
#  3   MW Median     244 non-null    int64
#  4   South Median  244 non-null    int64
#  5   West Median   244 non-null    int64
#  6   US Avg        244 non-null    int64
#  7   NE Avg        244 non-null    int64
#  8   MW Avg        244 non-null    int64
#  9   South Avg     244 non-null    int64
#  10  West Avg      244 non-null    int64
#  11  Year          244 non-null    object
#  12  Quarter       244 non-null    object
# dtypes: int64(10), object(3)
# memory usage: 24.9+ KB

# %%
value_qrt.plot(kind = 'line',
                      x = 'Year',
                      y = ['US Avg','NE Avg', 'MW Avg', 'South Avg', 'West Avg'],
                      figsize = (10,6))
# Out:
# <Axes: xlabel='Year'>

# %%
value_qrt.plot(kind = 'line',
                      x = 'Year',
                      y = ['US Avg'],
                      figsize = (10,6))
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### 1.	Is there a correlation between home values and inflation?

# %%
cpi = pd.read_csv('../capstone/data/cpi_50.csv')

# %% [markdown]
# https://www.bls.gov/cpi/tables/supplemental-files/

# %%
cpi
# Out:
#     Year      CPI
# 0   1963   30.400
# 1   1964   30.900
# 2   1965   31.200
# 3   1966   31.800
# 4   1967   32.900
# ..   ...      ...
# 57  2020  257.971
# 58  2021  261.582
# 59  2022  281.148
# 60  2023  299.170
# 61  2024  308.417
#
# [62 rows x 2 columns]

# %%
cpi['Inflation']= cpi['CPI'].pct_change()*100

# %%
cpi
# Out:
#     Year      CPI  Inflation
# 0   1963   30.400        NaN
# 1   1964   30.900   1.644737
# 2   1965   31.200   0.970874
# 3   1966   31.800   1.923077
# 4   1967   32.900   3.459119
# ..   ...      ...        ...
# 57  2020  257.971   2.486572
# 58  2021  261.582   1.399770
# 59  2022  281.148   7.479872
# 60  2023  299.170   6.410147
# 61  2024  308.417   3.090885
#
# [62 rows x 3 columns]

# %%
cpi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Year       62 non-null     int64
#  1   CPI        62 non-null     float64
#  2   Inflation  61 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 1.6 KB

# %%
cpi.mean()
# Out:
# Year         1993.500000
# CPI           143.273210
# Inflation       3.909166
# dtype: float64

# %%
home_merge = pd.merge(home_sales, cpi,
                      left_on = 'Period', right_on = 'Year',
                      how = 'inner')
home_merge
# Out:
#     Period  US Median  NE Median  MW Median  South Median  West Median  \
# 0     1963      18000      20300      17900         16100        18800
# 1     1964      18900      20300      19400         16700        20400
# 2     1965      20000      21500      21600         17500        21600
# 3     1966      21400      23500      23200         18200        23200
# 4     1967      22700      25400      25100         19400        24100
# ..     ...        ...        ...        ...           ...          ...
# 56    2019     321500     482500     289200        289000       408000
# 57    2020     336900     470700     298100        299000       412600
# 58    2021     397100     560900     339900        355900       510400
# 59    2022     457800     640200     405000        412700       578800
# 60    2023     427400     756200     394700        386900       533800
#
#     US Avg  NE Avg  MW Avg  South Avg  ...  South Median Pct Chng  \
# ...

# %%
home_corr = home_merge[['US Median', 'CPI']]
home_corr
# Out:
#     US Median      CPI
# 0       18000   30.400
# 1       18900   30.900
# 2       20000   31.200
# 3       21400   31.800
# 4       22700   32.900
# ..        ...      ...
# 56     321500  251.712
# 57     336900  257.971
# 58     397100  261.582
# 59     457800  281.148
# 60     427400  299.170
#
# [61 rows x 2 columns]

# %%
home_avg = home_merge[['Period', 'US Avg']]
home_avg
# Out:
#     Period  US Avg
# 0     1963   19300
# 1     1964   20500
# 2     1965   21500
# 3     1966   23300
# 4     1967   24600
# ..     ...     ...
# 56    2019  383900
# 57    2020  391900
# 58    2021  464200
# 59    2022  540000
# 60    2023  511100
#
# [61 rows x 2 columns]

# %%
home_corr['US Median ROI']= home_corr['US Median'].pct_change()*100
home_corr
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\1431262125.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   home_corr['US Median ROI']= home_corr['US Median'].pct_change()*100
#     US Median      CPI  US Median ROI
# 0       18000   30.400            NaN
# 1       18900   30.900       5.000000
# 2       20000   31.200       5.820106
# 3       21400   31.800       7.000000
# 4       22700   32.900       6.074766
# ..        ...      ...            ...
# 56     321500  251.712      -1.501225
# 57     336900  257.971       4.790047
# 58     397100  261.582      17.868804
# 59     457800  281.148      15.285822
# 60     427400  299.170      -6.640454
#
# [61 rows x 3 columns]

# %%
home_corr.mean()
# Out:
# US Median        153247.540984
# CPI                 140.565934
# US Median ROI         5.564195
# dtype: float64

# %%
home_corr_year = home_merge[['Period', 'US Median', 'CPI']]
home_corr_year
# Out:
#     Period  US Median      CPI
# 0     1963      18000   30.400
# 1     1964      18900   30.900
# 2     1965      20000   31.200
# 3     1966      21400   31.800
# 4     1967      22700   32.900
# ..     ...        ...      ...
# 56    2019     321500  251.712
# 57    2020     336900  257.971
# 58    2021     397100  261.582
# 59    2022     457800  281.148
# 60    2023     427400  299.170
#
# [61 rows x 3 columns]

# %%
home_merge['US Median']= cpi['CPI'].pct_change()*100

# %%
home_corr
# Out:
#     US Median      CPI
# 0       18000   30.400
# 1       18900   30.900
# 2       20000   31.200
# 3       21400   31.800
# 4       22700   32.900
# ..        ...      ...
# 56     321500  251.712
# 57     336900  257.971
# 58     397100  261.582
# 59     457800  281.148
# 60     427400  299.170
#
# [61 rows x 2 columns]

# %%
home_corr_year.to_csv('../capstone/data/home_corr_BI.csv')

# %%
home_corr.corr()
# Out:
#            US Median       CPI
# US Median   1.000000  0.971553
# CPI         0.971553  1.000000

# %% [markdown]
# ax1 = fig.add_subplot(111)
# ax1.plot(series1_x, series1_y, zorder=3)

# %%
home_merge.plot(kind = 'line',
                x = 'Period',
                y = 'CPI',
                figsize = (10,6))
# Out:
# <Axes: xlabel='Period'>

# %%
nashville = pd.read_csv('../capstone/data/zillow_nashville.csv')

# %%
nashville
# Out:
#            Date  Nashville, TN
# 0     1/31/2000      138455.74
# 1     2/29/2000      138604.42
# 2     3/31/2000      138776.58
# 3     4/30/2000      139162.52
# 4     5/31/2000      139586.39
# ..          ...            ...
# 285  10/31/2023      431414.42
# 286  11/30/2023      431675.61
# 287  12/31/2023      431627.02
# 288   1/31/2024      431695.72
# 289   2/29/2024      432557.20
#
# [290 rows x 2 columns]

# %%
nashville.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 290 entries, 0 to 289
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           290 non-null    object
#  1   Nashville, TN  290 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 4.7+ KB

# %%
nashville[["Month", "Day", "Year"]] = nashville['Date'].str.split('/', expand = True)
nashville
# Out:
#            Date  Nashville, TN Month Day  Year
# 0     1/31/2000      138455.74     1  31  2000
# 1     2/29/2000      138604.42     2  29  2000
# 2     3/31/2000      138776.58     3  31  2000
# 3     4/30/2000      139162.52     4  30  2000
# 4     5/31/2000      139586.39     5  31  2000
# ..          ...            ...   ...  ..   ...
# 285  10/31/2023      431414.42    10  31  2023
# 286  11/30/2023      431675.61    11  30  2023
# 287  12/31/2023      431627.02    12  31  2023
# 288   1/31/2024      431695.72     1  31  2024
# 289   2/29/2024      432557.20     2  29  2024
#
# [290 rows x 5 columns]

# %%
nashville = nashville.drop(columns=['Date'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[183], line 1
# ----> 1 nashville = nashville.drop(columns=['Date'])
#       2 nashville
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5258, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5110 def drop(
#    5111     self,
#    5112     labels: IndexLabel = None,
#    (...)
#    5119     errors: IgnoreRaise = "raise",
#    5120 ) -> DataFrame | None:
#    5121     """
#    5122     Drop specified labels from rows or columns.
#    5123
#    (...)
#    5256             weight  1.0     0.8
#    5257     """
# -> 5258     return super().drop(
#    5259         labels=labels,
#    5260         axis=axis,
#    5261         index=index,
#    5262         columns=columns,
#    5263         level=level,
#    5264         inplace=inplace,
#    5265         errors=errors,
# ...

# %%
nashville
# Out:
#      Nashville, TN Month Day  Year
# 0        138455.74     1  31  2000
# 1        138604.42     2  29  2000
# 2        138776.58     3  31  2000
# 3        139162.52     4  30  2000
# 4        139586.39     5  31  2000
# ..             ...   ...  ..   ...
# 285      431414.42    10  31  2023
# 286      431675.61    11  30  2023
# 287      431627.02    12  31  2023
# 288      431695.72     1  31  2024
# 289      432557.20     2  29  2024
#
# [290 rows x 4 columns]

# %%
nashville = nashville.groupby('Year')[['Nashville, TN']].mean().reset_index()
nashville
# Out:
#     Year  Nashville, TN
# 0   2000  140216.390833
# 1   2001  144734.120833
# 2   2002  148154.326667
# 3   2003  151501.745000
# 4   2004  156400.540833
# 5   2005  165199.400000
# 6   2006  177113.230833
# 7   2007  186474.601667
# 8   2008  185626.301667
# 9   2009  178048.490833
# 10  2010  173625.649167
# 11  2011  166575.614167
# 12  2012  165919.855000
# 13  2013  174253.345833
# 14  2014  185459.410000
# 15  2015  202748.764167
# 16  2016  226791.538333
# 17  2017  251886.842500
# 18  2018  273628.559167
# 19  2019  285624.540833
# 20  2020  302914.143333
# 21  2021  350088.241667
# 22  2022  428198.335000
# 23  2023  429696.423333
# 24  2024  432126.460000

# %%
nashville.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           25 non-null     object
#  1   Nashville, TN  25 non-null     float64
# dtypes: float64(1), object(1)
# memory usage: 532.0+ bytes

# %%
nashville['Year'] = nashville['Year'].astype(int)

# %%
nashville.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           25 non-null     int32
#  1   Nashville, TN  25 non-null     float64
# dtypes: float64(1), int32(1)
# memory usage: 432.0 bytes

# %%
nashville_merge = pd.merge(nashville, home_corr_year,
                           left_on = 'Year', right_on = 'Year',
                           how = 'inner')
nashville_merge
# Out:
#     Year  Nashville, TN      CPI
# 0   2000  140216.390833  168.800
# 1   2001  144734.120833  175.100
# 2   2002  148154.326667  177.100
# 3   2003  151501.745000  181.700
# 4   2004  156400.540833  185.200
# 5   2005  165199.400000  190.700
# 6   2006  177113.230833  198.300
# 7   2007  186474.601667  202.416
# 8   2008  185626.301667  211.080
# 9   2009  178048.490833  211.143
# 10  2010  173625.649167  216.687
# 11  2011  166575.614167  220.223
# 12  2012  165919.855000  226.665
# 13  2013  174253.345833  230.280
# 14  2014  185459.410000  233.916
# 15  2015  202748.764167  233.707
# 16  2016  226791.538333  236.916
# 17  2017  251886.842500  242.839
# 18  2018  273628.559167  247.867
# 19  2019  285624.540833  251.712
# 20  2020  302914.143333  257.971
# 21  2021  350088.241667  261.582
# 22  2022  428198.335000  281.148
# 23  2023  429696.423333  299.170
# 24  2024  432126.460000  308.417

# %%
nashville_us = pd.merge(nashville, home_avg,
                        left_on = 'Year', right_on = 'Period',
                        how = 'inner')
nashville_us
# Out:
#     Year  Nashville, TN  Period  US Avg
# 0   2000  140216.390833    2000  207000
# 1   2001  144734.120833    2001  213200
# 2   2002  148154.326667    2002  228700
# 3   2003  151501.745000    2003  246300
# 4   2004  156400.540833    2004  274500
# 5   2005  165199.400000    2005  297000
# 6   2006  177113.230833    2006  305900
# 7   2007  186474.601667    2007  313600
# 8   2008  185626.301667    2008  292600
# 9   2009  178048.490833    2009  270900
# 10  2010  173625.649167    2010  272900
# 11  2011  166575.614167    2011  267900
# 12  2012  165919.855000    2012  292200
# 13  2013  174253.345833    2013  324500
# 14  2014  185459.410000    2014  347700
# 15  2015  202748.764167    2015  352700
# 16  2016  226791.538333    2016  360900
# 17  2017  251886.842500    2017  384900
# 18  2018  273628.559167    2018  385000
# 19  2019  285624.540833    2019  383900
# 20  2020  302914.143333    2020  391900
# 21  2021  350088.241667    2021  464200
# ...

# %%
nashville_us = nashville_us[['Year', 'US Avg', 'Nashville, TN']]
nashville_us
# Out:
#     Year  US Avg  Nashville, TN
# 0   2000  207000  140216.390833
# 1   2001  213200  144734.120833
# 2   2002  228700  148154.326667
# 3   2003  246300  151501.745000
# 4   2004  274500  156400.540833
# 5   2005  297000  165199.400000
# 6   2006  305900  177113.230833
# 7   2007  313600  186474.601667
# 8   2008  292600  185626.301667
# 9   2009  270900  178048.490833
# 10  2010  272900  173625.649167
# 11  2011  267900  166575.614167
# 12  2012  292200  165919.855000
# 13  2013  324500  174253.345833
# 14  2014  347700  185459.410000
# 15  2015  352700  202748.764167
# 16  2016  360900  226791.538333
# 17  2017  384900  251886.842500
# 18  2018  385000  273628.559167
# 19  2019  383900  285624.540833
# 20  2020  391900  302914.143333
# 21  2021  464200  350088.241667
# 22  2022  540000  428198.335000
# 23  2023  511100  429696.423333

# %%
nashville_merge['Nash_ROI']= nashville['Nashville, TN'].pct_change()*100

# %%
nashville_merge
# Out:
#     Year  Nashville, TN      CPI   Nash_ROI
# 0   2000  140216.390833  168.800        NaN
# 1   2001  144734.120833  175.100   3.221970
# 2   2002  148154.326667  177.100   2.363096
# 3   2003  151501.745000  181.700   2.259413
# 4   2004  156400.540833  185.200   3.233491
# 5   2005  165199.400000  190.700   5.625850
# 6   2006  177113.230833  198.300   7.211788
# 7   2007  186474.601667  202.416   5.285529
# 8   2008  185626.301667  211.080  -0.454914
# 9   2009  178048.490833  211.143  -4.082294
# 10  2010  173625.649167  216.687  -2.484066
# 11  2011  166575.614167  220.223  -4.060480
# 12  2012  165919.855000  226.665  -0.393671
# 13  2013  174253.345833  230.280   5.022600
# 14  2014  185459.410000  233.916   6.430903
# 15  2015  202748.764167  233.707   9.322446
# 16  2016  226791.538333  236.916  11.858407
# 17  2017  251886.842500  242.839  11.065362
# 18  2018  273628.559167  247.867   8.631541
# 19  2019  285624.540833  251.712   4.384039
# ...

# %%
nashville_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           25 non-null     int32
#  1   Nashville, TN  25 non-null     float64
#  2   CPI            25 non-null     float64
#  3   Nash_ROI       24 non-null     float64
# dtypes: float64(3), int32(1)
# memory usage: 832.0 bytes

# %%
nashville_merge['CPI_Rate']= nashville_merge['CPI'].pct_change()*100

# %%
nashville_merge.mean()
# Out:
# Year               2012.000000
# Nashville, TN    227320.274867
# CPI                 226.025560
# Nash_ROI              4.970609
# CPI_Rate              2.557013
# dtype: float64

# %%
nashville_us.to_csv('../capstone/data/nashville_us_BI.csv')

# %%
nashville_corr = nashville_merge[['Nashville, TN', 'CPI']]
nashville_corr.corr()
# Out:
#                Nashville, TN       CPI
# Nashville, TN       1.000000  0.919102
# CPI                 0.919102  1.000000

# %%
nashville_merge.to_csv('../capstone/data/nashville_BI.csv')

# %% [markdown]
# ### 2.	How do rates impact home values.

# %%
thirty_fixed = pd.read_csv('../capstone/data/MORTGAGE30US.csv')

# %% [markdown]
# https://fred.stlouisfed.org/series/MORTGAGE30US

# %%
thirty_fixed
# Out:
#            DATE  30 YEAR FIXED
# 0      4/2/1971           7.33
# 1      4/9/1971           7.31
# 2     4/16/1971           7.31
# 3     4/23/1971           7.31
# 4     4/30/1971           7.29
# ...         ...            ...
# 2763  3/14/2024           6.74
# 2764  3/21/2024           6.87
# 2765  3/28/2024           6.79
# 2766   4/4/2024           6.82
# 2767  4/11/2024           6.88
#
# [2768 rows x 2 columns]

# %%
thirty_fixed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2768 entries, 0 to 2767
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   DATE           2768 non-null   object
#  1   30 YEAR FIXED  2768 non-null   float64
#  2   Month          2768 non-null   object
#  3   Day            2768 non-null   object
#  4   Year           2768 non-null   object
# dtypes: float64(1), object(4)
# memory usage: 108.3+ KB

# %%
thirty_fixed
# Out:
#            DATE  30 YEAR FIXED
# 0      4/2/1971           7.33
# 1      4/9/1971           7.31
# 2     4/16/1971           7.31
# 3     4/23/1971           7.31
# 4     4/30/1971           7.29
# ...         ...            ...
# 2763  3/14/2024           6.74
# 2764  3/21/2024           6.87
# 2765  3/28/2024           6.79
# 2766   4/4/2024           6.82
# 2767  4/11/2024           6.88
#
# [2768 rows x 2 columns]

# %%
thirty_fixed[["Month", "Day", "Year"]] = thirty_fixed['DATE'].str.split('/', expand = True)

# %%
thirty_fixed
# Out:
#            DATE  30 YEAR FIXED Month Day  Year
# 0      4/2/1971           7.33     4   2  1971
# 1      4/9/1971           7.31     4   9  1971
# 2     4/16/1971           7.31     4  16  1971
# 3     4/23/1971           7.31     4  23  1971
# 4     4/30/1971           7.29     4  30  1971
# ...         ...            ...   ...  ..   ...
# 2763  3/14/2024           6.74     3  14  2024
# 2764  3/21/2024           6.87     3  21  2024
# 2765  3/28/2024           6.79     3  28  2024
# 2766   4/4/2024           6.82     4   4  2024
# 2767  4/11/2024           6.88     4  11  2024
#
# [2768 rows x 5 columns]

# %%
thirty_fixed_new = thirty_fixed.drop(columns=['DATE'])

# %%
thirty_fixed_new
# Out:
#       30 YEAR FIXED Month Day  Year
# 0              7.33     4   2  1971
# 1              7.31     4   9  1971
# 2              7.31     4  16  1971
# 3              7.31     4  23  1971
# 4              7.29     4  30  1971
# ...             ...   ...  ..   ...
# 2763           6.74     3  14  2024
# 2764           6.87     3  21  2024
# 2765           6.79     3  28  2024
# 2766           6.82     4   4  2024
# 2767           6.88     4  11  2024
#
# [2768 rows x 4 columns]

# %%
fixed_value_merge = pd.merge(value_qrt, thirty_fixed_new, 
                             left_on ='Year', right_on = 'Year',
                             how = 'inner')

# %%
fixed_value_merge
# Out:
#        US Median  NE Median  MW Median  South Median  West Median  US Avg  \
# 0          24300      31000      27100         21300        24700   27300
# 1          24300      31000      27100         21300        24700   27300
# 2          24300      31000      27100         21300        24700   27300
# 3          24300      31000      27100         21300        24700   27300
# 4          24300      31000      27100         21300        24700   27300
# ...          ...        ...        ...           ...          ...     ...
# 11007     417700     698000     363000        387300       517800  492300
# 11008     417700     698000     363000        387300       517800  492300
# 11009     417700     698000     363000        387300       517800  492300
# 11010     417700     698000     363000        387300       517800  492300
# 11011     417700     698000     363000        387300       517800  492300
#
#        NE Avg  MW Avg  South Avg  West Avg  Year Quarter  30 YEAR FIXED Month  \
# ...

# %%
fixed_value_merge = fixed_value_merge.groupby('Year')[['US Median', '30 YEAR FIXED']].mean().reset_index()
fixed_value_merge
# Out:
#     Year  US Median  30 YEAR FIXED
# 0   1971    25225.0       7.541750
# 1   1972    27525.0       7.383269
# 2   1973    32600.0       8.044808
# 3   1974    36050.0       9.187115
# 4   1975    39275.0       9.047115
# 5   1976    44225.0       8.865849
# 6   1977    48900.0       8.845192
# 7   1978    55850.0       9.641731
# 8   1979    62750.0      11.203654
# 9   1980    64750.0      13.742115
# 10  1981    68950.0      16.641509
# 11  1982    69225.0      16.043654
# 12  1983    75375.0      13.235385
# 13  1984    79950.0      13.877692
# 14  1985    84275.0      12.430192
# 15  1986    92025.0      10.187308
# 16  1987   104700.0      10.213396
# 17  1988   112225.0      10.341731
# 18  1989   120425.0      10.319423
# 19  1990   122300.0      10.129423
# 20  1991   119975.0       9.246538
# 21  1992   121375.0       8.390189
# 22  1993   126500.0       7.314615
# 23  1994   130425.0       8.380769
# 24  1995   133475.0       7.934615
# 25  1996   140250.0       7.806154
# ...

# %%
fixed_value_merge.to_csv('../capstone/data/30_year_fixed_BI.csv')

# %%
median_corr = fixed_value_merge[['US Median', '30 YEAR FIXED']]
median_corr.corr()
# Out:
#                US Median  30 YEAR FIXED
# US Median       1.000000      -0.730907
# 30 YEAR FIXED  -0.730907       1.000000

# %%
fixed_value_merge.plot(kind = 'line',
                       x = 'Year',
                       y = ['US Median'],
                       figsize = (10,6))
# Out:
# <Axes: xlabel='Year'>

# %%
fixed_value_merge.plot(kind = 'line',
                       x = 'Year',
                       y = ['30 YEAR FIXED'],
                       figsize = (10,6))
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# ### 3.	Is consumer confidence impacted by increasing home values?

# %%
con_sent = pd.read_csv('../capstone/data/consumer_sentiment.csv')
con_sent
# Out:
#      Quarter  Year  Index of Sentiment
# 0          1  1960               100.0
# 1          2  1960                93.3
# 2          3  1960                97.2
# 3          4  1960                90.1
# 4          1  1961                91.6
# ..       ...   ...                 ...
# 252        1  2023                64.6
# 253        2  2023                62.3
# 254        3  2023                69.6
# 255        4  2023                64.9
# 256        1  2024                78.4
#
# [257 rows x 3 columns]

# %%
con_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Quarter             257 non-null    int64
#  1   Year                257 non-null    int64
#  2   Index of Sentiment  257 non-null    float64
# dtypes: float64(1), int64(2)
# memory usage: 6.2 KB

# %%
con_sent['Quarter'] = con_sent['Quarter'].astype('str')

# %%
con_sent['Year'] = con_sent['Year'].astype('str')

# %%
con_sent.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 257 entries, 0 to 256
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Quarter             257 non-null    object
#  1   Year                257 non-null    object
#  2   Index of Sentiment  257 non-null    float64
# dtypes: float64(1), object(2)
# memory usage: 6.2+ KB

# %%
con_sent['combined'] = con_sent['Year'] +  con_sent['Quarter']
con_sent
# Out:
#     Quarter  Year  Index of Sentiment combined
# 0         1  1960               100.0    19601
# 1         2  1960                93.3    19602
# 2         3  1960                97.2    19603
# 3         4  1960                90.1    19604
# 4         1  1961                91.6    19611
# ..      ...   ...                 ...      ...
# 252       1  2023                64.6    20231
# 253       2  2023                62.3    20232
# 254       3  2023                69.6    20233
# 255       4  2023                64.9    20234
# 256       1  2024                78.4    20241
#
# [257 rows x 4 columns]

# %%
value_qrt
# Out:
#      US Median  NE Median  MW Median  South Median  West Median  US Avg  \
# 0        17800      20800      17500         16800        18000   19300
# 1        18000      20600      17700         15800        18900   19400
# 2        17900      19600      17800         15900        19000   19200
# 3        18500      20600      19100         15800        19500   19600
# 4        18500      20300      18700         16500        19600   19600
# ..         ...        ...        ...           ...          ...     ...
# 239     479500     686600     355000        448600       564600  552600
# 240     429000     727800     384900        385600       558200  505300
# 241     418500     744500     393800        374300       543500  503000
# 242     435400     893300     423100        394100       513200  521900
# 243     417700     698000     363000        387300       517800  492300
#
#       NE Avg  MW Avg  South Avg  West Avg  Year Quarter
# ...

# %%
value_qrt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   US Median     244 non-null    int64
#  1   NE Median     244 non-null    int64
#  2   MW Median     244 non-null    int64
#  3   South Median  244 non-null    int64
#  4   West Median   244 non-null    int64
#  5   US Avg        244 non-null    int64
#  6   NE Avg        244 non-null    int64
#  7   MW Avg        244 non-null    int64
#  8   South Avg     244 non-null    int64
#  9   West Avg      244 non-null    int64
#  10  Year          244 non-null    object
#  11  Quarter       244 non-null    object
# dtypes: int64(10), object(2)
# memory usage: 23.0+ KB

# %%
value_qrt['Year'] = value_qrt['Year'].astype('str')

# %%
value_qrt['Quarter'] = value_qrt['Quarter'].astype('str')

# %%
value_qrt['Combined'] = value_qrt['Year'] + value_qrt['Quarter']
value_qrt
# Out:
#      US Median  NE Median  MW Median  South Median  West Median  US Avg  \
# 0        17800      20800      17500         16800        18000   19300
# 1        18000      20600      17700         15800        18900   19400
# 2        17900      19600      17800         15900        19000   19200
# 3        18500      20600      19100         15800        19500   19600
# 4        18500      20300      18700         16500        19600   19600
# ..         ...        ...        ...           ...          ...     ...
# 239     479500     686600     355000        448600       564600  552600
# 240     429000     727800     384900        385600       558200  505300
# 241     418500     744500     393800        374300       543500  503000
# 242     435400     893300     423100        394100       513200  521900
# 243     417700     698000     363000        387300       517800  492300
#
#       NE Avg  MW Avg  South Avg  West Avg  Year Quarter Combined
# ...

# %%
con_sent_merge = pd.merge(con_sent, value_qrt, 
                          left_on ='combined', right_on = 'Combined',
                          how = 'inner')
con_sent_merge
# Out:
#     Quarter_x Year_x  Index of Sentiment combined  US Median  NE Median  \
# 0           1   1963                98.4    19631      17800      20800
# 1           2   1963                91.7    19632      18000      20600
# 2           3   1963                96.4    19633      17900      19600
# 3           4   1963                94.4    19634      18500      20600
# 4           1   1964                99.5    19641      18500      20300
# ..        ...    ...                 ...      ...        ...        ...
# 239         4   2022                58.8    20224     479500     686600
# 240         1   2023                64.6    20231     429000     727800
# 241         2   2023                62.3    20232     418500     744500
# 242         3   2023                69.6    20233     435400     893300
# 243         4   2023                64.9    20234     417700     698000
#
#      MW Median  South Median  West Median  US Avg   NE Avg  MW Avg  South Avg  \
# ...

# %%
con_sent_merge[['Year_x', 'Quarter_x', 'Index of Sentiment', 'US Median', 'US Avg']]
# Out:
#     Year_x Quarter_x  Index of Sentiment  US Median  US Avg
# 0     1963         1                98.4      17800   19300
# 1     1963         2                91.7      18000   19400
# 2     1963         3                96.4      17900   19200
# 3     1963         4                94.4      18500   19600
# 4     1964         1                99.5      18500   19600
# ..     ...       ...                 ...        ...     ...
# 239   2022         4                58.8     479500  552600
# 240   2023         1                64.6     429000  505300
# 241   2023         2                62.3     418500  503000
# 242   2023         3                69.6     435400  521900
# 243   2023         4                64.9     417700  492300
#
# [244 rows x 5 columns]

# %%
con_sent_merge.to_csv('../capstone/data/consumer_sentiment_BI.csv')

# %%
con_median_corr = con_sent_merge[['Index of Sentiment', 'US Median']]
con_median_corr
# Out:
#      Index of Sentiment  US Median
# 0                  98.4      17800
# 1                  91.7      18000
# 2                  96.4      17900
# 3                  94.4      18500
# 4                  99.5      18500
# ..                  ...        ...
# 239                58.8     479500
# 240                64.6     429000
# 241                62.3     418500
# 242                69.6     435400
# 243                64.9     417700
#
# [244 rows x 2 columns]

# %%
con_median_corr.corr()
# Out:
#                     Index of Sentiment  US Median
# Index of Sentiment            1.000000  -0.144696
# US Median                    -0.144696   1.000000

# %%
con_avg_corr = con_sent_merge[['Index of Sentiment', 'US Avg']]
con_avg_corr
# Out:
#      Index of Sentiment  US Avg
# 0                  98.4   19300
# 1                  91.7   19400
# 2                  96.4   19200
# 3                  94.4   19600
# 4                  99.5   19600
# ..                  ...     ...
# 239                58.8  552600
# 240                64.6  505300
# 241                62.3  503000
# 242                69.6  521900
# 243                64.9  492300
#
# [244 rows x 2 columns]

# %%
con_avg_corr.corr()
# Out:
#                     Index of Sentiment    US Avg
# Index of Sentiment            1.000000 -0.141505
# US Avg                       -0.141505  1.000000

# %% [markdown]
# ### 4.	How have home values grown compared to wages? How has the disparity increased over the past 50 years?

# %%
median_weekly = pd.read_csv('./data/median_weekly_earnings.csv')

# %% [markdown]
# https://fred.stlouisfed.org/tags/series?t=wages

# %%
median_weekly
# Out:
#           DATE  Median Weekly Earnings
# 0     1/1/1979                   232.0
# 1     4/1/1979                   239.0
# 2     7/1/1979                   243.0
# 3    10/1/1979                   248.0
# 4     1/1/1980                   254.0
# ..         ...                     ...
# 176   1/1/2023                  1095.0
# 177   4/1/2023                  1107.0
# 178   7/1/2023                  1119.0
# 179  10/1/2023                  1142.0
# 180   1/1/2024                  1136.0
#
# [181 rows x 2 columns]

# %%
median_weekly[["Month", "Day", "Year"]] = median_weekly['DATE'].str.split('/', expand = True)
median_weekly
# Out:
#           DATE  Median Weekly Earnings Month Day  Year
# 0     1/1/1979                   232.0     1   1  1979
# 1     4/1/1979                   239.0     4   1  1979
# 2     7/1/1979                   243.0     7   1  1979
# 3    10/1/1979                   248.0    10   1  1979
# 4     1/1/1980                   254.0     1   1  1980
# ..         ...                     ...   ...  ..   ...
# 176   1/1/2023                  1095.0     1   1  2023
# 177   4/1/2023                  1107.0     4   1  2023
# 178   7/1/2023                  1119.0     7   1  2023
# 179  10/1/2023                  1142.0    10   1  2023
# 180   1/1/2024                  1136.0     1   1  2024
#
# [181 rows x 5 columns]

# %%
median_weekly = median_weekly.groupby('Year')['Median Weekly Earnings'].mean().reset_index()
median_weekly
# Out:
#     Year  Median Weekly Earnings
# 0   1979                  240.50
# 1   1980                  261.50
# 2   1981                  283.00
# 3   1982                  301.25
# 4   1983                  313.00
# 5   1984                  326.00
# 6   1985                  343.50
# 7   1986                  358.50
# 8   1987                  373.00
# 9   1988                  385.25
# 10  1989                  399.50
# 11  1990                  412.25
# 12  1991                  426.50
# 13  1992                  440.25
# 14  1993                  458.25
# 15  1994                  466.75
# 16  1995                  479.00
# 17  1996                  490.25
# 18  1997                  503.25
# 19  1998                  524.25
# 20  1999                  548.50
# 21  2000                  575.00
# 22  2001                  595.75
# 23  2002                  608.25
# 24  2003                  619.50
# 25  2004                  638.00
# 26  2005                  650.75
# ...

# %%
fixed_value_merge
# Out:
#     Year  US Median  30 YEAR FIXED
# 0   1971    25225.0       7.541750
# 1   1972    27525.0       7.383269
# 2   1973    32600.0       8.044808
# 3   1974    36050.0       9.187115
# 4   1975    39275.0       9.047115
# 5   1976    44225.0       8.865849
# 6   1977    48900.0       8.845192
# 7   1978    55850.0       9.641731
# 8   1979    62750.0      11.203654
# 9   1980    64750.0      13.742115
# 10  1981    68950.0      16.641509
# 11  1982    69225.0      16.043654
# 12  1983    75375.0      13.235385
# 13  1984    79950.0      13.877692
# 14  1985    84275.0      12.430192
# 15  1986    92025.0      10.187308
# 16  1987   104700.0      10.213396
# 17  1988   112225.0      10.341731
# 18  1989   120425.0      10.319423
# 19  1990   122300.0      10.129423
# 20  1991   119975.0       9.246538
# 21  1992   121375.0       8.390189
# 22  1993   126500.0       7.314615
# 23  1994   130425.0       8.380769
# 24  1995   133475.0       7.934615
# 25  1996   140250.0       7.806154
# ...

# %%
wages_merge = pd.merge(fixed_value_merge, median_weekly, 
                       left_on ='Year', right_on = 'Year',
                       how = 'inner')

# %%
wages_merge
# Out:
#     Year  US Median  30 YEAR FIXED  Median Weekly Earnings
# 0   1979    62750.0      11.203654                  240.50
# 1   1980    64750.0      13.742115                  261.50
# 2   1981    68950.0      16.641509                  283.00
# 3   1982    69225.0      16.043654                  301.25
# 4   1983    75375.0      13.235385                  313.00
# 5   1984    79950.0      13.877692                  326.00
# 6   1985    84275.0      12.430192                  343.50
# 7   1986    92025.0      10.187308                  358.50
# 8   1987   104700.0      10.213396                  373.00
# 9   1988   112225.0      10.341731                  385.25
# 10  1989   120425.0      10.319423                  399.50
# 11  1990   122300.0      10.129423                  412.25
# 12  1991   119975.0       9.246538                  426.50
# 13  1992   121375.0       8.390189                  440.25
# 14  1993   126500.0       7.314615                  458.25
# ...

# %%
wages_merge['Med Monthly Wages'] = wages_merge['Median Weekly Earnings']*4.3
wages_merge
# Out:
#     Year  US Median  30 YEAR FIXED  Median Weekly Earnings  Med Monthly Wages
# 0   1979    62750.0      11.203654                  240.50           1034.150
# 1   1980    64750.0      13.742115                  261.50           1124.450
# 2   1981    68950.0      16.641509                  283.00           1216.900
# 3   1982    69225.0      16.043654                  301.25           1295.375
# 4   1983    75375.0      13.235385                  313.00           1345.900
# 5   1984    79950.0      13.877692                  326.00           1401.800
# 6   1985    84275.0      12.430192                  343.50           1477.050
# 7   1986    92025.0      10.187308                  358.50           1541.550
# 8   1987   104700.0      10.213396                  373.00           1603.900
# 9   1988   112225.0      10.341731                  385.25           1656.575
# 10  1989   120425.0      10.319423                  399.50           1717.850
# ...

# %%
wages_merge['30 YEAR PMT'] = wages_merge['30 YEAR FIXED']/100

# %%
wages_merge.head(1)
# Out:
#    Year  US Median  30 YEAR FIXED  Median Weekly Earnings  Med Monthly Wages  \
# 0  1979    62750.0      11.203654                   240.5            1034.15
#
#    30 YEAR PMT
# 0     0.112037

# %% [markdown]
# npf.pmt(0.075/12, 12*15, 200000)
# -1854.0247200054619

# %%
wages_merge['Mortgage'] = npf.pmt((wages_merge['30 YEAR PMT']/12), 12*30, -(wages_merge['US Median']))

# %%
wages_merge.head(5)
# Out:
#    Year  US Median  30 YEAR FIXED  Median Weekly Earnings  Med Monthly Wages  \
# 0  1979    62750.0      11.203654                  240.50           1034.150
# 1  1980    64750.0      13.742115                  261.50           1124.450
# 2  1981    68950.0      16.641509                  283.00           1216.900
# 3  1982    69225.0      16.043654                  301.25           1295.375
# 4  1983    75375.0      13.235385                  313.00           1345.900
#
#    30 YEAR PMT    Mortgage
# 0     0.112037  607.259052
# 1     0.137421  754.007470
# 2     0.166415  962.959049
# 3     0.160437  933.345208
# 4     0.132354  847.687895

# %%
wages_merge['Pct Of Income'] = (wages_merge['Mortgage']/wages_merge['Med Monthly Wages'])*100

# %%
wages_merge
# Out:
#     Year  US Median  30 YEAR FIXED  Median Weekly Earnings  Med Monthly Wages  \
# 0   1979    62750.0      11.203654                  240.50           1034.150
# 1   1980    64750.0      13.742115                  261.50           1124.450
# 2   1981    68950.0      16.641509                  283.00           1216.900
# 3   1982    69225.0      16.043654                  301.25           1295.375
# 4   1983    75375.0      13.235385                  313.00           1345.900
# 5   1984    79950.0      13.877692                  326.00           1401.800
# 6   1985    84275.0      12.430192                  343.50           1477.050
# 7   1986    92025.0      10.187308                  358.50           1541.550
# 8   1987   104700.0      10.213396                  373.00           1603.900
# 9   1988   112225.0      10.341731                  385.25           1656.575
# 10  1989   120425.0      10.319423                  399.50           1717.850
# ...

# %%
wages_merge.to_csv('../capstone/data/percent_of_income.csv')

# %% [markdown]
# ### 5.	How have home values increased compared to stock values. Have homes become a better investment than stocks.

# %% [markdown]
# https://www.spglobal.com/spdji/en/indices/equity/sp-500/#overview

# %%
sp500 = pd.read_csv('../capstone/data/sp500.csv')
sp500
# Out:
#      Effective date   S&P 500
# 0          4/17/2019  2900.45
# 1          4/18/2019  2905.03
# 2          4/22/2019  2907.97
# 3          4/23/2019  2933.68
# 4          4/24/2019  2927.25
# ...              ...      ...
# 1180      12/22/2023  4754.63
# 1181      12/26/2023  4774.75
# 1182      12/27/2023  4781.58
# 1183      12/28/2023  4783.35
# 1184      12/29/2023  4769.83
#
# [1185 rows x 2 columns]

# %%
sp500[["Month", "Day", "Year"]] = sp500['Effective date '].str.split('/', expand = True)
sp500
# Out:
#      Effective date   S&P 500 Month Day  Year
# 0          4/17/2019  2900.45     4  17  2019
# 1          4/18/2019  2905.03     4  18  2019
# 2          4/22/2019  2907.97     4  22  2019
# 3          4/23/2019  2933.68     4  23  2019
# 4          4/24/2019  2927.25     4  24  2019
# ...              ...      ...   ...  ..   ...
# 1180      12/22/2023  4754.63    12  22  2023
# 1181      12/26/2023  4774.75    12  26  2023
# 1182      12/27/2023  4781.58    12  27  2023
# 1183      12/28/2023  4783.35    12  28  2023
# 1184      12/29/2023  4769.83    12  29  2023
#
# [1185 rows x 5 columns]

# %%
sp500.columns = sp500.columns.str.strip()

# %%
sp500
# Out:
#      Effective date  S&P 500 Month Day  Year
# 0         4/17/2019  2900.45     4  17  2019
# 1         4/18/2019  2905.03     4  18  2019
# 2         4/22/2019  2907.97     4  22  2019
# 3         4/23/2019  2933.68     4  23  2019
# 4         4/24/2019  2927.25     4  24  2019
# ...             ...      ...   ...  ..   ...
# 1180     12/22/2023  4754.63    12  22  2023
# 1181     12/26/2023  4774.75    12  26  2023
# 1182     12/27/2023  4781.58    12  27  2023
# 1183     12/28/2023  4783.35    12  28  2023
# 1184     12/29/2023  4769.83    12  29  2023
#
# [1185 rows x 5 columns]

# %%
sp500 = sp500.drop(columns=['Effective date'])
sp500
# Out:
#       S&P 500 Month Day  Year
# 0     2900.45     4  17  2019
# 1     2905.03     4  18  2019
# 2     2907.97     4  22  2019
# 3     2933.68     4  23  2019
# 4     2927.25     4  24  2019
# ...       ...   ...  ..   ...
# 1180  4754.63    12  22  2023
# 1181  4774.75    12  26  2023
# 1182  4781.58    12  27  2023
# 1183  4783.35    12  28  2023
# 1184  4769.83    12  29  2023
#
# [1185 rows x 4 columns]

# %%
sp500.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1185 entries, 0 to 1184
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   S&P 500  1185 non-null   float64
#  1   Month    1185 non-null   object
#  2   Day      1185 non-null   object
#  3   Year     1185 non-null   object
# dtypes: float64(1), object(3)
# memory usage: 37.2+ KB

# %%
sp500['Month'] = sp500['Month'].astype(int)

# %%
sp500['Day'] = sp500['Day'].astype(int)

# %%
sp500['Year'] = sp500['Year'].astype(int)

# %%
sp500monthly = sp500.loc[sp500.Day == 17]
sp500monthly
# Out:
#       S&P 500  Month  Day  Year
# 0     2900.45      4   17  2019
# 21    2859.53      5   17  2019
# 41    2889.67      6   17  2019
# 62    2984.42      7   17  2019
# 105   3005.70      9   17  2019
# 127   2997.95     10   17  2019
# 169   3192.52     12   17  2019
# 190   3329.62      1   17  2020
# 230   2529.19      3   17  2020
# 252   2874.56      4   17  2020
# 294   3113.49      6   17  2020
# 315   3224.73      7   17  2020
# 336   3381.99      8   17  2020
# 358   3357.01      9   17  2020
# 401   3609.53     11   17  2020
# 422   3722.48     12   17  2020
# 462   3931.33      2   17  2021
# 482   3974.12      3   17  2021
# 524   4163.29      5   17  2021
# 546   4221.86      6   17  2021
# 588   4448.08      8   17  2021
# 610   4432.99      9   17  2021
# 653   4688.67     11   17  2021
# 674   4620.64     12   17  2021
# 716   4380.26      2   17  2022
# 735   4411.67      3   17  2022
# 777   4088.85      5   17  2022
# 799   3674.84      6   17  2022
# ...

# %%
sp500monthly['Return']= sp500monthly['S&P 500'].pct_change()*100
sp500monthly
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\1501083677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sp500monthly['Return']= sp500monthly['S&P 500'].pct_change()*100
#       S&P 500  Month  Day  Year     Return
# 0     2900.45      4   17  2019        NaN
# 21    2859.53      5   17  2019  -1.410816
# 41    2889.67      6   17  2019   1.054019
# 62    2984.42      7   17  2019   3.278921
# 105   3005.70      9   17  2019   0.713036
# 127   2997.95     10   17  2019  -0.257843
# 169   3192.52     12   17  2019   6.490102
# 190   3329.62      1   17  2020   4.294413
# 230   2529.19      3   17  2020 -24.039680
# 252   2874.56      4   17  2020  13.655360
# 294   3113.49      6   17  2020   8.311881
# ...

# %%
values = pd.read_csv('../capstone/data/value_by_quarter2019.csv')
values
# Out:
#     Year  Quarter  US Median  NE Median  MW Median  South Median  West Median  \
# 0   2019        1     313000     480300     288700        280000       402000
# 1   2019        2     322500     453500     273800        292400       411400
# 2   2019        3     318400     543400     294700        289900       399600
# 3   2019        4     327100     469500     284200        290900       417500
# 4   2020        1     329000     512100     288300        279900       411900
# 5   2020        2     322600     441000     287200        290600       404300
# 6   2020        3     337500     449500     311700        294600       403000
# 7   2020        4     358700     508100     294600        320000       427300
# 8   2021        1     369800     511700     320600        327300       473500
# 9   2021        2     382600     543800     324100        342200       490200
# 10  2021        3     411200     523800     358800        372500       516000
# ...

# %%
values = values[['Year', 'Quarter', 'US Avg', 'NE Avg', 'MW Avg', 'South Avg', 'West Avg']]
values
# Out:
#     Year  Quarter  US Avg   NE Avg  MW Avg  South Avg  West Avg
# 0   2019        1  375500   595700  315900     330300    457700
# 1   2019        2  376700   608200  310600     334500    464400
# 2   2019        3  382700   688600  326800     332500    471600
# 3   2019        4  384600   526900  335300     340700    477700
# 4   2020        1  383000   645200  337000     325300    471300
# 5   2020        2  374500   608300  329800     327000    457800
# 6   2020        3  397800   609000  364100     349600    470800
# 7   2020        4  403900   624200  338500     367100    479100
# 8   2021        1  418600   620200  356500     369200    518000
# 9   2021        2  440600   722900  370000     391000    531600
# 10  2021        3  473000   731500  394900     418300    598200
# 11  2021        4  497300   737900  414600     451800    591600
# 12  2022        1  514100   766400  432000     451000    627700
# 13  2022        2  527500   707000  438700     482000    647300
# ...

# %%
values['US ROI']= values['US Avg'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\3137061595.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values['US ROI']= values['US Avg'].pct_change()*100

# %%
values['NE ROI']= values['NE Avg'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\3566504864.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values['NE ROI']= values['NE Avg'].pct_change()*100

# %%
values['MW ROI']= values['MW Avg'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\3289133616.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values['MW ROI']= values['MW Avg'].pct_change()*100

# %%
values['South ROI']= values['South Avg'].pct_change()*100
# Out:
# C:\Users\mew4v\AppData\Local\Temp\ipykernel_36428\488993298.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values['South ROI']= values['South Avg'].pct_change()*100

# %%
values['West ROI']= values['West Avg'].pct_change()*100

# %%
values
# Out:
#     Year  Quarter  US Avg   NE Avg  MW Avg  South Avg  West Avg    US ROI  \
# 0   2019        1  375500   595700  315900     330300    457700       NaN
# 1   2019        2  376700   608200  310600     334500    464400  0.319574
# 2   2019        3  382700   688600  326800     332500    471600  1.592779
# 3   2019        4  384600   526900  335300     340700    477700  0.496472
# 4   2020        1  383000   645200  337000     325300    471300 -0.416017
# 5   2020        2  374500   608300  329800     327000    457800 -2.219321
# 6   2020        3  397800   609000  364100     349600    470800  6.221629
# 7   2020        4  403900   624200  338500     367100    479100  1.533434
# 8   2021        1  418600   620200  356500     369200    518000  3.639515
# 9   2021        2  440600   722900  370000     391000    531600  5.255614
# 10  2021        3  473000   731500  394900     418300    598200  7.353609
# 11  2021        4  497300   737900  414600     451800    591600  5.137421
# ...

# %%
values.to_csv('../capstone/data/valuesROI.csv')

# %%
sp500monthly.to_csv('../capstone/data/sp500ROI.csv')

# %% [markdown]
# ### Stretch: What percent of new builds are related to the cost materials and labor? How has that changed over the years?
